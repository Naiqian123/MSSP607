# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pushd "/content/drive/MyDrive/MSSP607/Modules/Week10/"
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/MSSP607/Modules/Week10/'
# /content
# ['/content']

# %%
# Configure plotting in Jupyter
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams.update({
    'figure.figsize': (7.5, 7.5),
    'axes.spines.right': False,
    'axes.spines.left': False,
    'axes.spines.top': False,
    'axes.spines.bottom': False})
# Seed random number generator
import random
from numpy import random as nprand
seed = hash("Network Science in Python") % 2**32
nprand.seed(seed)
random.seed(seed)

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()

# 添加5个节点
G.add_nodes_from(['Naiqian Zhang', 'Astrid Fan', 'Qiyao Huang', 'Mingxuan Li', 'Longsha Wei'])

# 添加边来表示他们之间的关系
G.add_edges_from([('Naiqian Zhang', 'Astrid Fan'),
                  ('Naiqian Zhang', 'Qiyao Huang'),
                  ('Naiqian Zhang', 'Mingxuan Li'),
                  ('Naiqian Zhang', 'Longsha Wei'),
                  ('Astrid Fan', 'Qiyao Huang'),
                  ('Astrid Fan', 'Mingxuan Li'),
                  ('Astrid Fan', 'Longsha Wei'),
                  ('Qiyao Huang', 'Mingxuan Li'),
                  ('Qiyao Huang', 'Longsha Wei'),
                  ('Mingxuan Li', 'Longsha Wei')])

plt.figure(figsize=(10, 10))
nx.draw_networkx(G)
plt.show()
